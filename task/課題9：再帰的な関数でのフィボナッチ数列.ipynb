# %% [markdown]
# # 課題9：再帰的な関数でのフィボナッチ数列
#
# このNotebookでは、再帰的な関数を使ってフィボナッチ数列を計算します。

# %%
# 1. prognum.pyからfibonacci関数をインポート
from prognum import fibonacci

# %%
# 2. ユーザーから「何番目の数値を求めたいか」を入力してもらう
n = int(input("何番目の数値を求めますか？："))

# %%
# 3. fibonacci関数を実行して、結果を表示する
result = fibonacci(n)
print(result)
# Out:
# 55

# %% [markdown]
# # 命令1: 名前の入力

# %%
# 名前を入力してもらい、変数nameに格納
name = input("名前を入力してください: ")

# %% [markdown]
# # 命令2: 年齢の入力

# %%
# 現在の年齢を入力してもらい、変数ageに格納
age = int(input("現在の年齢を入力してください: "))

# %% [markdown]
# # 命令3: 結果の表示

# %%
# 来年の年齢を計算して表示
next_age = age + 1
print(f"私の名前は {name} です。来年で {next_age} 歳になります。")
# Out:
# 私の名前は bob です。来年で 60 歳になります。
